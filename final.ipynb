# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

bank = pd.read_csv('Resources/BankChurners.csv')
bank
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
bank.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
cleanbank = bank.drop(columns=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])
cleanbank
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
sns.histplot(cleanbank['Education_Level'],color='y');

# %%
cleanbank.shape
# Out:
# (10127, 21)

# %%
sns.histplot(cleanbank['Customer_Age'],color='b');

# %%
sns.histplot(cleanbank['Total_Revolving_Bal'],color='r');

# %%
sns.histplot(cleanbank['Credit_Limit'],color='g');

# %%
cleanbank['Gender'].value_counts(normalize=True).plot(kind='pie',autopct='%1.1f%%', title= "Gender")
# Out:
# <AxesSubplot:title={'center':'Gender'}, ylabel='Gender'>

# %%
cleanbank[['Education_Level','Gender','Marital_Status']].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# Education_Level  Gender  Marital_Status
# Graduate         F       Married           0.076824
#                  M       Married           0.069221
#                  F       Single            0.063889
#                  M       Single            0.054310
# High School      F       Married           0.047398
#                  M       Married           0.046312
#                  F       Single            0.040585
#                  M       Single            0.036635
# Unknown          F       Married           0.035549
#                          Single            0.034265
# Uneducated       F       Married           0.033771
# Unknown          M       Married           0.032389
# Uneducated       F       Single            0.031697
#                  M       Married           0.031006
# Unknown          M       Single            0.027056
# Uneducated       M       Single            0.026168
# College          F       Married           0.023600
# ...

# %%
cleanbank['Attrition_Flag'].value_counts().plot(kind='bar',color = ['tab:orange','tab:green'], title= 'Type of Customer',
                                           xlabel= 'Type of Customer', ylabel='Count')
# Out:
# <AxesSubplot:title={'center':'Type of Customer'}, xlabel='Type of Customer', ylabel='Count'>

# %%
cleanbank['Education_Level'].value_counts().plot(kind='bar',title='Education Level', xlabel='Education Level',ylabel='Count', color = ['b','orange','g','r','m','cyan','y'])
# Out:
# <AxesSubplot:title={'center':'Education Level'}, xlabel='Education Level', ylabel='Count'>

# %%
gender_grp = cleanbank.groupby(by='Gender')
male_income = gender_grp['Income_Category'].value_counts().loc['M']
female_income = gender_grp['Income_Category'].value_counts().loc['F']

# %%
plt.plot(male_income,color = 'orange')
plt.plot(female_income,color = 'g')
plt.title("Income Category by Gender")
# Out:
# Text(0.5, 1.0, 'Income Category by Gender')

# %%
female_income
# Out:
# Income_Category
# Less than $40K    3284
# Unknown           1060
# $40K - $60K       1014
# Name: Income_Category, dtype: int64

# %%
male_income
# Out:
# Income_Category
# $80K - $120K      1535
# $60K - $80K       1402
# $40K - $60K        776
# $120K +            727
# Less than $40K     277
# Unknown             52
# Name: Income_Category, dtype: int64

# %%
male_card = gender_grp['Card_Category'].value_counts().loc['M']
female_card = gender_grp['Card_Category'].value_counts().loc['F']

# %%
sns.countplot(data=cleanbank,x='Gender',hue='Card_Category',order=cleanbank['Gender'].value_counts().index,palette='turbo')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
gender_income = cleanbank.groupby(by=['Gender','Income_Category','Marital_Status'])
gender_income[['Credit_Limit','Total_Revolving_Bal']].mean().round().sort_values(by='Credit_Limit', ascending=False)
# Out:
#                                        Credit_Limit  Total_Revolving_Bal
# Gender Income_Category Marital_Status
# M      Unknown         Unknown              26028.0                428.0
#        $120K +         Single               21213.0               1186.0
#                        Unknown              20297.0               1325.0
#                        Married              18687.0               1261.0
#        $80K - $120K    Divorced             18475.0               1112.0
#        $120K +         Divorced             18326.0               1054.0
#        Unknown         Divorced             17451.0               1480.0
#        $80K - $120K    Unknown              16677.0               1105.0
#                        Single               16597.0               1138.0
#                        Married              14675.0               1291.0
#        $60K - $80K     Single               11925.0               1105.0
# ...
